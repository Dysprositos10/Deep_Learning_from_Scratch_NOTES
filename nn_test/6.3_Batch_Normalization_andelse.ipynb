# %% [markdown]
# 1.Batch Normalization:强制性”地调整激活值的分布：将 mini-batch 的输入数据 {x1, x2, . . . , xm} 变换为均值为 0、方差为 1 的数据
# ![1753625117146.png](attachment:1753625117146.png)

# %% [markdown]
# ![1753626129761.png](attachment:1753626129761.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 减少学习数据
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01


def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10, 
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
    
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
    
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
    
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
    
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list


# 3.绘制图形==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

# 在循环外部创建一个大画布 (4x4布局)
plt.figure(figsize=(20, 16))  # 调整整体画布大小以适应所有子图
plt.subplots_adjust(wspace=0.1, hspace=0.3)  # 调整子图间距

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
    plt.subplot(4,4,i+1) 
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')
    
plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.097 - 0.093
# epoch:1 | 0.097 - 0.106
# epoch:2 | 0.097 - 0.125
# epoch:3 | 0.097 - 0.143
# epoch:4 | 0.097 - 0.16
# epoch:5 | 0.097 - 0.171
# epoch:6 | 0.097 - 0.194
# epoch:7 | 0.097 - 0.218
# epoch:8 | 0.097 - 0.232
# epoch:9 | 0.097 - 0.258
# epoch:10 | 0.097 - 0.284
# epoch:11 | 0.097 - 0.296
# epoch:12 | 0.097 - 0.307
# epoch:13 | 0.097 - 0.333
# epoch:14 | 0.097 - 0.346
# epoch:15 | 0.097 - 0.364
# epoch:16 | 0.097 - 0.379
# epoch:17 | 0.097 - 0.395
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.097 - 0.409
# epoch:19 | 0.097 - 0.428
# ============== 2/16 ==============
# epoch:0 | 0.099 - 0.108
# epoch:1 | 0.097 - 0.091
# epoch:2 | 0.097 - 0.136
# epoch:3 | 0.097 - 0.176
# epoch:4 | 0.097 - 0.191
# epoch:5 | 0.097 - 0.214
# epoch:6 | 0.097 - 0.236
# epoch:7 | 0.097 - 0.254
# epoch:8 | 0.097 - 0.277
# ...

# %% [markdown]
# #     2过拟合：发生过拟合的原因，主要有以下两个
# ***
#     模型拥有大量参数、表现力强。
#     训练数据少

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 为了再现过拟合，减少学习数据
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（权值衰减）的设定 =======================
#weight_decay_lambda = 0 # 不使用权值衰减的情况
weight_decay_lambda = 0
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 用学习率为 0.01 的 SGD 更新参数

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.绘制图形==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.10333333333333333, test acc:0.104
# epoch:1, train acc:0.13, test acc:0.1192
# epoch:2, train acc:0.16, test acc:0.1344
# epoch:3, train acc:0.2, test acc:0.1529
# epoch:4, train acc:0.23, test acc:0.1757
# epoch:5, train acc:0.25, test acc:0.1898
# epoch:6, train acc:0.28, test acc:0.2121
# epoch:7, train acc:0.31, test acc:0.2565
# epoch:8, train acc:0.36666666666666664, test acc:0.2868
# epoch:9, train acc:0.38, test acc:0.2909
# epoch:10, train acc:0.4033333333333333, test acc:0.3175
# epoch:11, train acc:0.41333333333333333, test acc:0.3226
# epoch:12, train acc:0.4266666666666667, test acc:0.3397
# epoch:13, train acc:0.44666666666666666, test acc:0.3388
# epoch:14, train acc:0.45666666666666667, test acc:0.3542
# epoch:15, train acc:0.49, test acc:0.3593
# epoch:16, train acc:0.52, test acc:0.3707
# epoch:17, train acc:0.5066666666666667, test acc:0.3754
# epoch:18, train acc:0.52, test acc:0.3818
# epoch:19, train acc:0.5166666666666667, test acc:0.3772
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 为了再现过拟合，减少学习数据
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（权值衰减）的设定 =======================
#weight_decay_lambda = 0 # 不使用权值衰减的情况
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 用学习率为 0.01 的 SGD 更新参数

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.绘制图形==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.14666666666666667, test acc:0.1108
# epoch:1, train acc:0.18, test acc:0.1248
# epoch:2, train acc:0.19666666666666666, test acc:0.1398
# epoch:3, train acc:0.22333333333333333, test acc:0.1584
# epoch:4, train acc:0.25, test acc:0.1756
# epoch:5, train acc:0.2833333333333333, test acc:0.1946
# epoch:6, train acc:0.31666666666666665, test acc:0.218
# epoch:7, train acc:0.35, test acc:0.2372
# epoch:8, train acc:0.36333333333333334, test acc:0.2613
# epoch:9, train acc:0.37, test acc:0.2811
# epoch:10, train acc:0.4166666666666667, test acc:0.3007
# epoch:11, train acc:0.44, test acc:0.3167
# epoch:12, train acc:0.47333333333333333, test acc:0.3336
# epoch:13, train acc:0.49, test acc:0.3507
# epoch:14, train acc:0.49333333333333335, test acc:0.3625
# epoch:15, train acc:0.5, test acc:0.3802
# epoch:16, train acc:0.5233333333333333, test acc:0.3918
# epoch:17, train acc:0.5466666666666666, test acc:0.4189
# epoch:18, train acc:0.5566666666666666, test acc:0.429
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 在测试模式下使用`return x * (1.0 - self.dropout_ratio)`是为了在测试时对神经元的输出进行缩放，以补偿训练时因Dropout导致的激活值期望的变化。这样做的目的是为了在测试时（不使用Dropout）能够得到与训练时（使用Dropout）相近的输出范围，从而保持网络行为的稳定性。
# ### 详细解释：
# 在训练过程中，由于Dropout随机丢弃了一部分神经元（比例为`dropout_ratio`），因此每个神经元在训练时只有`1 - dropout_ratio`的概率被保留。也就是说，每个神经元的输出期望值（即多次训练的平均输出）是原来的`1 - dropout_ratio`倍。
# 例如，假设一个神经元的原始输出为`x`，在训练时，它被保留的概率是`1 - dropout_ratio`，被丢弃的概率是`dropout_ratio`。那么它的期望输出为：
# ```
# E[output] = (1 - dropout_ratio) * x + dropout_ratio * 0 = (1 - dropout_ratio) * x
# ```
# 在测试时，我们不希望随机丢弃神经元（因为需要模型稳定且快速地进行预测），所以我们会使用所有的神经元。但是，如果我们在测试时直接使用原始输出`x`（即不进行缩放），那么该神经元的输出就会是`x`，这比训练时的期望输出`(1-dropout_ratio)*x`要大。为了保持训练和测试时输出的期望值一致，我们在测试时对每个神经元的输出乘以`(1 - dropout_ratio)`，即：
# ```
# 测试时输出 = x * (1 - dropout_ratio)
# ```
# 这样，测试时的输出期望就和训练时一致了。

# %%
#Dropout方法：复杂网络模型——训练时，随机选出隐藏层的神经元，然后将其删除。被删除的神经元不再进行信号的传递
class Dropout:
    def __init__(self, dropout_ratio=0.5): #dropout_ratio`：丢弃率，表示每个神经元被丢弃的概率。默认值为0.5，即50%的神经元会被随机丢弃
        self.dropout_ratio = dropout_ratio
        self.mask = None #mask：记录哪些神经元被保留/丢弃的布尔矩阵（训练时生成，反向传播时复用）
    def forward(self, x, train_flg=True): #训练模式 (train_flg=True)目的：在训练过程中引入随机性，防止过拟合
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio # >：self.dropout_ratio 将随机数转为布尔值
            return x * self.mask #被丢弃的神经元输出归零（相当于删除）；>True保留，＜False丢弃（结果都要乘上mask）
        #在Python中，布尔数组与数值数组相乘时，`True`被视为1，`False`被视为0
        else:#在预测/推理时使用完整的网络能力：不丢弃任何神经元，但将所有输出值按比例缩小 
            return x * (1.0 - self.dropout_ratio)
def backward(self, dout):
    return dout * self.mask # 使用相同的掩码，被丢弃的神经元（mask=0）梯度为 0 → 权重不更新；保留的神经元（mask=1）正常更新权重

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 为了再现过拟合，减少学习数据
x_train = x_train[:300]
t_train = t_train[:300]

# 设定是否使用Dropuout，以及比例 ========================
use_dropout = True  # 不使用Dropout的情况下为False
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# 绘制图形==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.2797131589574304
# === epoch:1, train acc:0.11333333333333333, test acc:0.0843 ===
# train loss:2.2950030856122314
# train loss:2.293427077018362
# train loss:2.285887344370413
# === epoch:2, train acc:0.11, test acc:0.0874 ===
# train loss:2.2842668785663416
# train loss:2.279772824311302
# train loss:2.289117322689441
# === epoch:3, train acc:0.11, test acc:0.088 ===
# train loss:2.2999302187359136
# train loss:2.283069751135165
# train loss:2.3013038141708932
# === epoch:4, train acc:0.10666666666666667, test acc:0.0857 ===
# train loss:2.3012062407804716
# train loss:2.2807269530993133
# train loss:2.2933687157958147
# === epoch:5, train acc:0.12, test acc:0.0929 ===
# train loss:2.2770372860159025
# train loss:2.2796569612336537
# train loss:2.2821275418515383
# === epoch:6, train acc:0.11333333333333333, test acc:0.0956 ===
# train loss:2.2614287954540337
# train loss:2.311611530022113
# train loss:2.2787361769726706
# ...

# %% [markdown]
# # 3.超参数（hyper-parameter）
# 指各层的神经元数量、batch 大小、参数更新时的学习率或权值衰减等
#
#
# 根据不同的数据集，有的会事先分成训练数据、验证数据、测试数据三
# 部分，有的只分成训练数据和测试数据两部分，有的则不进行分割。在这种
# 情况下，用户需要自行进行分割。如果是 MNIST 数据集，获得验证数据的
# 最简单的方法就是从训练数据中事先分割
# 20% 作为验证数据

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.util import shuffle_dataset
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 为了实现高速化，减少训练数据
x_train = x_train[:500]
t_train = t_train[:500]

# 分割验证数据
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50): #weight_decay：权重衰减系数 (L2正则化强度)，用于防止过拟合;epocs：训练轮数，默认为50轮
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda = weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


# 超参数的随机搜索======================================
optimization_trial = 100 #尝试100组不同的超参数组合
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 指定搜索的超参数的范围===============
    weight_decay = 10 ** np.random.uniform(-8, -4) #添加正则化项
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay) #对于每一组超参数，我们训练模型时遍历整个训练数据集的次数（这里是50次）
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    #这个列表包含了模型在训练过程中每个epoch结束时在验证集上的准确率
    #即输出验证集最终准确率，当前学习率，当前权重衰减值
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# 绘制图形========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# val acc:0.13 | lr:3.202180374360553e-05, weight decay:1.1869237116426667e-06
# val acc:0.8 | lr:0.0095115360205531, weight decay:4.198510053183037e-06
# val acc:0.82 | lr:0.009891056975628752, weight decay:1.7398100504445072e-08
# val acc:0.07 | lr:4.5221383650314796e-06, weight decay:2.0916834949283916e-06
# val acc:0.12 | lr:2.120047169244424e-05, weight decay:9.837554764269588e-06
# val acc:0.09 | lr:8.884772911048304e-06, weight decay:3.8244652317492684e-07
# val acc:0.08 | lr:3.913004521434797e-06, weight decay:5.7709156038349016e-05
# val acc:0.8 | lr:0.007462567361056289, weight decay:2.1862199887795116e-08
# val acc:0.16 | lr:1.69506939841504e-06, weight decay:5.511709402611993e-05
# val acc:0.13 | lr:0.00018096557398086476, weight decay:3.9817755924212305e-06
# val acc:0.04 | lr:0.00011803658143406582, weight decay:1.312289514472166e-05
# val acc:0.08 | lr:2.6251994697474168e-05, weight decay:1.3984950007224268e-08
# ...
